# %% [markdown]
# ## Doctor Visit Analysis

# %%
# Load Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## Load the dataset

# %%
df=pd.read_csv("DoctorVisits - DA.csv")
df
# Out:
#       Unnamed: 0  visits  gender   age  income  illness  reduced  health  \
# 0              1       1  female  0.19    0.55        1        4       1
# 1              2       1  female  0.19    0.45        1        2       1
# 2              3       1    male  0.19    0.90        3        0       0
# 3              4       1    male  0.19    0.15        1        0       0
# 4              5       1    male  0.19    0.45        2        5       1
# ...          ...     ...     ...   ...     ...      ...      ...     ...
# 5185        5186       0  female  0.22    0.55        0        0       0
# 5186        5187       0    male  0.27    1.30        0        0       1
# 5187        5188       0  female  0.37    0.25        1        0       1
# 5188        5189       0  female  0.52    0.65        0        0       0
# 5189        5190       0    male  0.72    0.25        0        0       0
#
#      private freepoor freerepat nchronic lchronic
# ...

# %%
## First 15 rows

df.head(15)
# Out:
#     Unnamed: 0  visits  gender   age  income  illness  reduced  health  \
# 0            1       1  female  0.19    0.55        1        4       1
# 1            2       1  female  0.19    0.45        1        2       1
# 2            3       1    male  0.19    0.90        3        0       0
# 3            4       1    male  0.19    0.15        1        0       0
# 4            5       1    male  0.19    0.45        2        5       1
# 5            6       1  female  0.19    0.35        5        1       9
# 6            7       1  female  0.19    0.55        4        0       2
# 7            8       1  female  0.19    0.15        3        0       6
# 8            9       1  female  0.19    0.65        2        0       5
# 9           10       1    male  0.19    0.15        1        0       0
# 10          11       1    male  0.19    0.45        1        0       0
# 11          12       1    male  0.19    0.25        2        0       2
# ...

# %%
# shape

# %%
df.shape
# Out:
# (5190, 13)

# %%
# columns

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'visits', 'gender', 'age', 'income', 'illness', 'reduced',
#        'health', 'private', 'freepoor', 'freerepat', 'nchronic', 'lchronic'],
#       dtype='object')

# %%
# dtypes

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# visits          int64
# gender         object
# age           float64
# income        float64
# illness         int64
# reduced         int64
# health          int64
# private        object
# freepoor       object
# freerepat      object
# nchronic       object
# lchronic       object
# dtype: object

# %%
# nunique

# %%
df.nunique()
# Out:
# Unnamed: 0    5190
# visits          10
# gender           2
# age             12
# income          14
# illness          6
# reduced         15
# health          13
# private          2
# freepoor         2
# freerepat        2
# nchronic         2
# lchronic         2
# dtype: int64

# %%
# info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5190 entries, 0 to 5189
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5190 non-null   int64
#  1   visits      5190 non-null   int64
#  2   gender      5190 non-null   object
#  3   age         5190 non-null   float64
#  4   income      5190 non-null   float64
#  5   illness     5190 non-null   int64
#  6   reduced     5190 non-null   int64
#  7   health      5190 non-null   int64
#  8   private     5190 non-null   object
#  9   freepoor    5190 non-null   object
#  10  freerepat   5190 non-null   object
#  11  nchronic    5190 non-null   object
#  12  lchronic    5190 non-null   object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 527.2+ KB

# %%
# summary

# %%
df.describe()
# Out:
#         Unnamed: 0       visits          age       income      illness  \
# count  5190.000000  5190.000000  5190.000000  5190.000000  5190.000000
# mean   2595.500000     0.301734     0.406385     0.583160     1.431985
# std    1498.368279     0.798134     0.204782     0.368907     1.384152
# min       1.000000     0.000000     0.190000     0.000000     0.000000
# 25%    1298.250000     0.000000     0.220000     0.250000     0.000000
# 50%    2595.500000     0.000000     0.320000     0.550000     1.000000
# 75%    3892.750000     0.000000     0.620000     0.900000     2.000000
# max    5190.000000     9.000000     0.720000     1.500000     5.000000
#
#            reduced       health
# count  5190.000000  5190.000000
# mean      0.861850     1.217534
# std       2.887628     2.124266
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       0.000000     0.000000
# 75%       0.000000     2.000000
# max      14.000000    12.000000

# %%
# Total No of people based on their count of illness

# %%
df['illness'].value_counts()
# Out:
# illness
# 1    1638
# 0    1554
# 2     946
# 3     542
# 4     274
# 5     236
# Name: count, dtype: int64

# %%
df['gender'].value_counts()
# Out:
# gender
# female    2702
# male      2488
# Name: count, dtype: int64

# %%
# Visulize and analyse the max, min and medium income

# %%
y=list(df.income)
plt.boxplot(y)
plt.show()

# %%
# no of days of reduced activity of male and female seperately due to illness

# %%
df.groupby('gender')['reduced'].mean()
# Out:
# gender
# female    0.975574
# male      0.738344
# Name: reduced, dtype: float64

# %%
df.groupby('gender')['reduced'].mean()
# Out:
# gender
# female    0.975574
# male      0.738344
# Name: reduced, dtype: float64

# %%
df.head()
# Out:
#    Unnamed: 0  visits  gender   age  income  illness  reduced  health private  \
# 0           1       1  female  0.19    0.55        1        4       1     yes
# 1           2       1  female  0.19    0.45        1        2       1     yes
# 2           3       1    male  0.19    0.90        3        0       0      no
# 3           4       1    male  0.19    0.15        1        0       0      no
# 4           5       1    male  0.19    0.45        2        5       1      no
#
#   freepoor freerepat nchronic lchronic
# 0       no        no       no       no
# 1       no        no       no       no
# 2       no        no       no       no
# 3       no        no       no       no
# 4       no        no      yes       no

# %%
## Visualize if there any missing values in the dataset based on heatmap

# %%
sns.heatmap(df.isnull(),cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
# Separate numerical and categorical columns
numerical_columns = [col for col in df.columns if df[col].dtype in ['int64', 'float64']]
categorical_columns = [col for col in df.columns if df[col].dtype == 'object']
print("Numerical Columns:", numerical_columns)
print("Categorical Columns:", categorical_columns)
# Out:
# Numerical Columns: ['Unnamed: 0', 'visits', 'age', 'income', 'illness', 'reduced', 'health']
# Categorical Columns: ['gender', 'private', 'freepoor', 'freerepat', 'nchronic', 'lchronic']

# %%
# Find out the correlation between variables in the given dataset correleation between different variables

# %%
numerical_data = df[numerical_columns]
corr_matrix = numerical_data.corr()
plt.figure(figsize=(10, 10))
sns.heatmap(corr_matrix, cbar=True, annot=True, cmap='Blues')
plt.show()

# %%
# Analyse how the income of a patient affects the no of visits to the hospital

# %%
#relation between income and visits
plt.figure(figsize=(10,10))
plt.scatter(x='income',y='visits',data=df)
plt.xlabel('income')
plt.ylabel('visits')
# Out:
# Text(0, 0.5, 'visits')

# %%
# Count and visualize the number of males and females affected by illness

# %%
sns.histplot(df.gender,bins=2)
# Out:
# C:\Users\bsrao\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='gender', ylabel='Count'>

# %%
# Visualize the percentage of people getting govt health insuarance due to low income due to old age and also the percentage of people having private health insurance

# %%
# of people getting govt Insurance due to low income

label=['yes', 'no'] 
Y =df [df['freepoor']=='yes']
N= df [df['freepoor']=='no']
x=[Y.shape[0], N.shape[0]]
plt.figure(figsize=(5,5)) 
plt.pie(x, labels=label)
plt.title("% of people getting govt health Insurance due to low income ")
plt.show()

# % of people having private Insurance
Y= df[df['private']=='yes']
N= df[df['private']=='no'] 
x = [Y.shape[0], N.shape[0]]
plt.figure(figsize=(5,5))
plt.pie(x, labels=label)
plt.title("% of people having private health Insurance ")
plt.show()

# % of people getting govt Insurance due to old age, disability or veteran status
Y = df [df['freerepat']=='yes']
N = df [df['freerepat']=='no']
x=[Y.shape[0],N.shape[0]] 
plt.figure(figsize=(5,5))
plt.pie(x, labels=label)
plt.title("$ of people getting govt health Insurance due to old age, disability or veteran status ") 
plt.show()

# %%
# Plot a horizontal bar chart to analyse the reduced days of activity due to illiness based on gender

# %%
db = df.groupby('gender')['reduced'].sum().reset_index()
print(db)
plt.barh(db['gender'], db['reduced'], color=['cornflowerblue', 'lightseagreen'])
plt.title('Bar Chart of Reduced Activity by Gender')
plt.xlabel('Reduced Activity')
plt.ylabel('Gender')
plt.show()
# Out:
#    gender  reduced
# 0  female     2636
# 1    male     1837

# %%
# How do healthcare visits vary for people with chronic vs. non-chronic conditions?

# %%
chronic_visits = df.groupby(['nchronic', 'lchronic'])['visits'].mean().reset_index()
print(chronic_visits)
plt.figure(figsize=(8, 6))
sns.barplot(x='nchronic', y='visits', hue='lchronic', data=chronic_visits)
plt.title('Average Healthcare Visits Based on Chronic Conditions')
plt.xlabel('Chronic Condition (nchronic)')
plt.ylabel('Average Visits')
plt.show()
# Out:
#   nchronic lchronic    visits
# 0       no       no  0.191737
# 1       no      yes  0.603306
# 2      yes       no  0.345602

# %%
# Does age or income influence the number of healthcare visits?

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'visits', 'gender', 'age', 'income', 'illness', 'reduced',
#        'health', 'private', 'freepoor', 'freerepat', 'nchronic', 'lchronic'],
#       dtype='object')

# %%
chronic_df = df[df['lchronic'] == 'yes']
plt.figure(figsize=(10, 6))

# Plot income vs visits for chronic individuals
sns.scatterplot(x='income', y='visits', data=chronic_df, hue='freepoor', style='freerepat', palette='coolwarm')
plt.title("Income and Free Healthcare Support Impact on Healthcare Visits (Chronic Conditions)")
plt.xlabel("Income")
plt.ylabel("Healthcare Visits")
plt.show()

# %%
# 4. What is the effect of gender on healthcare utilization among individuals with chronic diseases?
# We will compare healthcare visits by gender for individuals with chronic conditions
chronic_gender = chronic_df.groupby('gender')['visits'].sum().reset_index()

# Plot the result
plt.figure(figsize=(8, 6))
sns.barplot(x='gender', y='visits', data=chronic_gender)
plt.title("Healthcare Visits by Gender for Chronic Conditions")
plt.xlabel("Gender")
plt.ylabel("Total Healthcare Visits")
plt.show()

# %%
# Drop the 'Unnamed: 0' column
df = df.drop(columns=['Unnamed: 0'])

# %%
df.head()
# Out:
#    visits  gender   age  income  illness  reduced  health private freepoor  \
# 0       1  female  0.19    0.55        1        4       1     yes       no
# 1       1  female  0.19    0.45        1        2       1     yes       no
# 2       1    male  0.19    0.90        3        0       0      no       no
# 3       1    male  0.19    0.15        1        0       0      no       no
# 4       1    male  0.19    0.45        2        5       1      no       no
#
#   freerepat nchronic lchronic
# 0        no       no       no
# 1        no       no       no
# 2        no       no       no
# 3        no       no       no
# 4        no      yes       no

# %%
df.dtypes
# Out:
# visits         int64
# gender        object
# age          float64
# income       float64
# illness        int64
# reduced        int64
# health         int64
# private       object
# freepoor      object
# freerepat     object
# nchronic      object
# lchronic      object
# dtype: object

# %%
# Multiply 'age' by 100 and then convert to 'int64'
df['age'] = (df['age'] * 100).astype('int64')

# Round 'income' and convert to 'int64'
df['income'] =(df['income']*100).astype('int64')

# Print the data types to verify the changes
print(df.dtypes)
# Out:
# visits        int64
# gender       object
# age           int64
# income        int64
# illness       int64
# reduced       int64
# health        int64
# private      object
# freepoor     object
# freerepat    object
# nchronic     object
# lchronic     object
# dtype: object

# %%
df
# Out:
#       visits  gender  age  income  illness  reduced  health private freepoor  \
# 0          1  female   19      55        1        4       1     yes       no
# 1          1  female   19      45        1        2       1     yes       no
# 2          1    male   19      90        3        0       0      no       no
# 3          1    male   19      15        1        0       0      no       no
# 4          1    male   19      45        2        5       1      no       no
# ...      ...     ...  ...     ...      ...      ...     ...     ...      ...
# 5185       0  female   22      55        0        0       0      no       no
# 5186       0    male   27     130        0        0       1      no       no
# 5187       0  female   37      25        1        0       1      no       no
# 5188       0  female   52      65        0        0       0      no       no
# 5189       0    male   72      25        0        0       0      no       no
#
#      freerepat nchronic lchronic
# ...

# %%
df.isna().sum()
# Out:
# visits       0
# gender       0
# age          0
# income       0
# illness      0
# reduced      0
# health       0
# private      0
# freepoor     0
# freerepat    0
# nchronic     0
# lchronic     0
# dtype: int64

# %%
# Healthcare visits for chronic patients by healthcare plan type
chronic_plans = df[df['nchronic'] == 'yes'].groupby(['private', 'freepoor'])['visits'].mean().reset_index()
plt.figure(figsize=(8, 6))
sns.barplot(x='private', y='visits', hue='freepoor', data=chronic_plans)
plt.title('Healthcare Visits Based on Healthcare Plans for Chronic Conditions')
plt.xlabel('Private Healthcare Plan')
plt.ylabel('Average Visits')
plt.show()

# %%
# Healthcare visits by age and income for chronic patients
chronic_df = df[df['nchronic'] == 'yes']
plt.figure(figsize=(8, 6))
sns.scatterplot(x='age', y='income', size='visits', hue='visits', data=chronic_df, palette='viridis', sizes=(20, 200))
plt.title('Healthcare Visits by Age and Income for Chronic Conditions')
plt.xlabel('Age')
plt.ylabel('Income')
plt.legend(title='Visits')
plt.show()

# %%
# Compare healthcare visits based on chronic condition status (nchronic)
chronic_visits = df.groupby('nchronic')['visits'].mean().reset_index()
print(chronic_visits)

# Plot the results
plt.figure(figsize=(8, 6))
sns.barplot(x='nchronic', y='visits', data=chronic_visits)
plt.title('Average Healthcare Visits for Chronic vs Non-Chronic Conditions')
plt.xlabel('Chronic Condition (0 = No, 1 = Yes)')
plt.ylabel('Average Number of Visits')
plt.show()
# Out:
#   nchronic    visits
# 0       no  0.272111
# 1      yes  0.345602

# %%
# Healthcare visits by gender and chronic condition status

gender_chronic_visits = df.groupby(['gender', 'nchronic'])['visits'].mean().reset_index()
plt.figure(figsize=(8, 6))
sns.barplot(x='gender', y='visits', hue='nchronic', data=gender_chronic_visits)
plt.title('Healthcare Visits by Gender and Chronic Condition Status')
plt.xlabel('Gender')
plt.ylabel('Average Visits')
plt.show()

# %%
# Heatmap: Chronic Conditions and Visits by Age Group and Gender
df['age_group'] = pd.cut(df['age'], bins=[0, 30, 60, 100], labels=['0-30', '31-60', '61+'])
heatmap_data = df.pivot_table(index='age_group', columns='gender', values='visits', aggfunc='mean')
plt.figure(figsize=(8, 6))
sns.heatmap(heatmap_data, annot=True, cmap='coolwarm', cbar_kws={'label': 'Average Healthcare Visits'})
plt.title('Average Healthcare Visits by Age Group and Gender')
plt.xlabel('Gender')
plt.ylabel('Age Group')
plt.show()
# Out:
# C:\Users\bsrao\AppData\Local\Temp\ipykernel_11536\4084526209.py:3: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   heatmap_data = df.pivot_table(index='age_group', columns='gender', values='visits', aggfunc='mean')

# %%
# Compare healthcare visits based on chronic condition status (lchronic)
chronic_visits = df.groupby('lchronic')['visits'].mean().reset_index()
print(chronic_visits)

# Plot the results
plt.figure(figsize=(8, 6))
sns.barplot(x='lchronic', y='visits', data=chronic_visits)
plt.title('Average Healthcare Visits for Chronic vs Non-Chronic Conditions')
plt.xlabel('Chronic Condition (0 = No, 1 = Yes)')
plt.ylabel('Average Number of Visits')
plt.show()
# Out:
#   lchronic    visits
# 0       no  0.261941
# 1      yes  0.603306

# %%
df.columns
# Out:
# Index(['visits', 'gender', 'age', 'income', 'illness', 'reduced', 'health',
#        'private', 'freepoor', 'freerepat', 'nchronic', 'lchronic',
#        'age_group'],
#       dtype='object')

# %%
# Plot the distribution of chronic conditions (nchronic, lchronic)
sns.countplot(x='nchronic', data=df)
plt.title('Distribution of Chronic Conditions (nchronic)')
plt.show()

sns.countplot(x='lchronic', data=df)
plt.title('Distribution of Long-Term Chronic Conditions (lchronic)')
plt.show()

# %%
# Bar plot for visits by healthcare type (private vs freepoor or freerepat)
plt.figure(figsize=(10,6))
sns.barplot(x='private', y='visits', data=df)
plt.title('Healthcare Visits by Healthcare Type')
plt.xlabel('Private Healthcare (0=No, 1=Yes)')
plt.ylabel('Average Number of Visits')
plt.show()

# %%
# Histogram to show the distribution of healthcare visits
plt.figure(figsize=(10,6))
sns.histplot(df['visits'], bins=20, kde=True)
plt.title('Distribution of Healthcare Visits')
plt.xlabel('Number of Visits')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\bsrao\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
